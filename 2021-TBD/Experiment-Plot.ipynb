# %%
import os
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
metric = {}
names = ['fashion_mnist', 'cifar10', 'fashion_mnistf', 'cifar10f', 'caltech', 'caltechff', 'caltechfc']
for name in names:
    with open(f'{name}.pickle', 'rb') as f:
        metric[f'{name}'] = pickle.load(f)
metric.keys()
# Out:
# dict_keys(['fashion_mnist', 'cifar10', 'fashion_mnistf', 'cifar10f', 'caltech', 'caltechff', 'caltechfc'])

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot()
ax.plot(metric['fashion_mnist'][1], linestyle='--', color='blue', label='Fashion MNIST from scratch')
ax.plot(metric['cifar10'][1], linestyle='--', color='green', label='CIFAR10 from scratch')
ax.plot(metric['fashion_mnistf'][1], linestyle='-', color='blue', label='Fashion MNIST using fork')
ax.plot(metric['cifar10f'][1], linestyle='-', color='green', label='CIFAR10 using fork')

ax.set_xlabel('Rounds', fontsize='x-large')
ax.set_ylabel('Test Accuracy', fontsize='x-large')
ax.set_ylim([-0.05, 1.05])
ax.tick_params(axis='both', labelsize='large')
ax.legend(loc='lower right', fontsize='large')

ax.axhline(y=0.9101, linestyle='dashdot', color='brown', alpha=0.75)
# ax.text(-4, 0.9101, round(0.9101, 2),
#         fontsize='medium', 
#         horizontalalignment='center', verticalalignment='center')
ax.axhline(y=metric['fashion_mnistf'][1][25], xmax=25/50, linestyle='dotted', color='gray')
ax.axvline(x=25, ymax=metric['fashion_mnistf'][1][25]-0.03, linestyle='dotted', color='gray')
ax.text(-1, metric['fashion_mnistf'][1][25], round(metric['fashion_mnistf'][1][25], 2),
        fontsize='medium', 
        horizontalalignment='center', verticalalignment='center')
ax.text(25, -0.03, 25,
        fontsize='medium', 
        horizontalalignment='center', verticalalignment='center')

ax.axhline(y=0.7087, linestyle='dashdot', color='brown', alpha=0.75)
# ax.text(-4, 0.7087, round(0.7087, 2),
#         fontsize='medium', 
#         horizontalalignment='center', verticalalignment='center')
ax.axhline(y=metric['cifar10f'][1][12], xmax=12/50, linestyle='dotted', color='gray')
ax.axvline(x=12, ymax=metric['cifar10f'][1][25]-0.06, linestyle='dotted', color='gray')
ax.text(-1, metric['cifar10f'][1][12], round(metric['cifar10f'][1][12], 2),
        fontsize='medium', 
        horizontalalignment='center', verticalalignment='center')
ax.text(12, -0.03, 12,
        fontsize='medium', 
        horizontalalignment='center', verticalalignment='center')

fig.savefig('accuracy.png', bbox_inches='tight')

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot()
ax.plot(range(1, 26), metric['fashion_mnist'][1][1:26], linestyle='--', color='blue', label='Fashion MNIST from scratch')
ax.plot(range(1, 26), metric['cifar10'][1][1:26], linestyle='--', color='green', label='CIFAR10 from scratch')
ax.plot(range(1, 26), metric['fashion_mnistf'][1][1:26], linestyle='-', color='blue', label='Fashion MNIST using fork')
ax.plot(range(1, 26), metric['cifar10f'][1][1:26], linestyle='-', color='green', label='CIFAR10 using fork')

ax.set_xlabel('Rounds', fontsize='x-large')
ax.set_ylabel('Test Accuracy', fontsize='x-large')
ax.set_ylim([-0.05, 1.05])
ax.tick_params(axis='both', labelsize='large')
ax.legend(loc='lower right', fontsize='large')

ax.axhline(y=0.9101, linestyle='dashdot', color='brown', alpha=0.75)
# ax.text(-4, 0.9101, round(0.9101, 2),
#         fontsize='medium', 
#         horizontalalignment='center', verticalalignment='center')
ax.axhline(y=metric['fashion_mnistf'][1][25], xmax=25/26, linestyle='dotted', color='gray')
ax.axvline(x=25, ymax=metric['fashion_mnistf'][1][25]-0.03, linestyle='dotted', color='gray')
ax.text(-1, metric['fashion_mnistf'][1][25], round(metric['fashion_mnistf'][1][25], 2),
        fontsize='medium', 
        horizontalalignment='center', verticalalignment='center')
ax.text(25, -0.03, 25,
        fontsize='medium', 
        horizontalalignment='center', verticalalignment='center')

ax.axhline(y=0.7087, linestyle='dashdot', color='brown', alpha=0.75)
# ax.text(-4, 0.7087, round(0.7087, 2),
#         fontsize='medium', 
#         horizontalalignment='center', verticalalignment='center')
ax.axhline(y=metric['cifar10f'][1][12], xmax=12/26, linestyle='dotted', color='gray')
ax.axvline(x=12, ymax=metric['cifar10f'][1][25]-0.06, linestyle='dotted', color='gray')
ax.text(-1, metric['cifar10f'][1][12], round(metric['cifar10f'][1][12], 2),
        fontsize='medium', 
        horizontalalignment='center', verticalalignment='center')
ax.text(12, -0.03, 12,
        fontsize='medium', 
        horizontalalignment='center', verticalalignment='center')

fig.savefig('accuracy.png', bbox_inches='tight')

# %%
for index, (a, b) in enumerate(zip(metric['fashion_mnist'][1], metric['fashion_mnistf'][1])):
    if a >= b:
        print(index)
        break
for index, (a, b) in enumerate(zip(metric['cifar10'][1], metric['cifar10f'][1])):
    if a >= b and index != 0:
        print(index)
        break
# Out:
# 25
# 12

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot()
ax.plot(range(1, 26), metric['fashion_mnist'][0][1:26], linestyle='--', color='blue', label='Fashion MNIST from scratch')
ax.plot(range(1, 26), metric['cifar10'][0][1:26], linestyle='--', color='green', label='CIFAR10 from scratch')
ax.plot(range(1, 26), metric['fashion_mnistf'][0][1:26], linestyle='-', color='blue', label='Fashion MNIST using fork')
ax.plot(range(1, 26), metric['cifar10f'][0][1:26], linestyle='-', color='green', label='CIFAR10 using fork')

ax.set_xlabel('Rounds', fontsize='x-large')
ax.set_ylabel('Test Loss', fontsize='x-large')
ax.set_ylim([-0.05, 2.05])
ax.tick_params(axis='both', labelsize='large')
ax.legend(loc='upper right', fontsize='large')

ax.axhline(y=metric['fashion_mnistf'][0][19], xmax=19/len(metric['fashion_mnistf'][0]), linestyle='dotted', color='gray')
ax.axvline(x=19, ymax=metric['fashion_mnistf'][0][19]/max(metric['fashion_mnistf'][0]), linestyle='dotted', color='gray')
ax.text(-1, metric['fashion_mnistf'][0][19], round(metric['fashion_mnistf'][0][19], 2),
        fontsize='medium', 
        horizontalalignment='center', verticalalignment='center')
ax.text(19, 0.2, 19,
        fontsize='medium', 
        horizontalalignment='center', verticalalignment='center')

ax.axhline(y=metric['cifar10f'][0][12], xmax=12/len(metric['cifar10f'][0]), linestyle='dotted', color='gray')
ax.axvline(x=12, ymax=metric['cifar10f'][0][12]-0.565, linestyle='dotted', color='gray')
ax.text(-1, metric['cifar10f'][0][12], round(metric['cifar10f'][0][12], 2),
        fontsize='medium', 
        horizontalalignment='center', verticalalignment='center')
ax.text(12, 0.2, 12,
        fontsize='medium', 
        horizontalalignment='center', verticalalignment='center')

fig.savefig('loss.png', bbox_inches='tight')

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot()
ax.plot(range(1, 52), metric['caltech'][1][1:], linestyle='-', color='tab:olive', label='Caltech Bird 200 from scratch')
ax.plot(range(1, 52), metric['caltechff'][1][1:], linestyle='-', color='tab:cyan', label='Caltech Bird 200 forked from Fashion MNIST')
ax.plot(range(1, 52), metric['caltechfc'][1][1:], linestyle='-', color='tab:red', label='Caltech Bird 200 forked from CIFAR10')


ax.set_xlabel('Rounds', fontsize='x-large')
ax.set_ylabel('Train Accuracy', fontsize='x-large')
ax.set_ylim([-0.05, 1.05])
ax.tick_params(axis='both', labelsize='large')
ax.legend(loc='lower right', fontsize='large')

fig.savefig('fork.png', bbox_inches='tight')

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot()
ax.plot(metric['fashion_mnist'][0][1:], linestyle='--', color='blue', label='Fashion MNIST from scratch')
ax.plot(metric['cifar10'][0][1:], linestyle='--', color='green', label='CIFAR10 from scratch')
ax.plot(metric['fashion_mnistf'][0][1:], linestyle='-', color='blue', label='Fashion MNIST using fork')
ax.plot(metric['cifar10f'][0][1:], linestyle='-', color='green', label='CIFAR10 using fork')

ax.set_xlabel('Rounds', fontsize='x-large')
ax.set_ylabel('Test Loss', fontsize='x-large')
# ax.set_ylim([-0.05, 1.05])
ax.tick_params(axis='both', labelsize='large')
ax.legend(loc='upper right', fontsize='large')

ax.axhline(y=metric['fashion_mnistf'][0][19], xmax=19/len(metric['fashion_mnistf'][0]), linestyle='dotted', color='gray')
ax.axvline(x=19, ymax=metric['fashion_mnistf'][0][19]/max(metric['fashion_mnistf'][0]), linestyle='dotted', color='gray')
ax.text(-1, metric['fashion_mnistf'][0][19], round(metric['fashion_mnistf'][0][19], 2),
        fontsize='medium', 
        horizontalalignment='center', verticalalignment='center')
ax.text(19, 0.2, 19,
        fontsize='medium', 
        horizontalalignment='center', verticalalignment='center')

ax.axhline(y=metric['cifar10f'][0][12], xmax=12/len(metric['cifar10f'][0]), linestyle='dotted', color='gray')
ax.axvline(x=12, ymax=metric['cifar10f'][0][12]-0.565, linestyle='dotted', color='gray')
ax.text(-1, metric['cifar10f'][0][12], round(metric['cifar10f'][0][12], 2),
        fontsize='medium', 
        horizontalalignment='center', verticalalignment='center')
ax.text(12, 0.2, 12,
        fontsize='medium', 
        horizontalalignment='center', verticalalignment='center')

fig.savefig('loss.png', bbox_inches='tight')

# %%
for index, (a, b) in enumerate(zip(metric['fashion_mnist'][0], metric['fashion_mnistf'][0])):
    if a <= b and index != 0:
        print(index)
        break
for index, (a, b) in enumerate(zip(metric['cifar10'][0], metric['cifar10f'][0])):
    if a <= b and index != 0:
        print(index)
        break
# Out:
# 19
# 12

# %%
metric['fashion_mnistf'][1][25]
# Out:
# 0.9088000059127808

# %%
def get_model_iterator(model, start, end):
    for micro in range(start, end):
        path = f'./models/{model}/v0.0.{micro}'
        yield path

# %%
def do_evaluate(model_name, test_root, start, end):
    loss = []
    acc = []
    classes = []
    for path in get_model_iterator(model_name, start, end):
        with open(os.path.join(path, 'labels.pickle'), 'rb') as f:
            classes = pickle.load(f)
        break
    image_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1/255)
    test_data = image_generator.flow_from_directory(test_root, classes=classes, 
                                                    target_size=(32, 32), shuffle=True)
    for path in get_model_iterator(model_name, start, end):
        print(path)
        model = tf.keras.models.load_model(os.path.abspath(os.path.expanduser(path)))
        metric = model.evaluate(test_data, verbose=0)
        loss.append(metric[0])
        acc.append(metric[1])
    return loss, acc

# %%
tf.__version__
# Out:
# '2.5.1'

# %%
model = tf.keras.models.load_model(os.path.abspath(os.path.expanduser('./models/cifar10/v0.0.1')))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-23-21d7f4cd03b4> in <module>
# ----> 1 model = tf.keras.models.load_model(os.path.abspath(os.path.expanduser('./models/cifar10/v0.0.1')))
#
# ~/Jupyter/tff/lib/python3.8/site-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     204         filepath = path_to_string(filepath)
#     205         if isinstance(filepath, str):
# --> 206           return saved_model_load.load(filepath, compile, options)
#     207
#     208   raise IOError(
#
# ~/Jupyter/tff/lib/python3.8/site-packages/tensorflow/python/keras/saving/saved_model/load.py in load(path, compile, options)
#     144   # Recreate layers and metrics using the info stored in the metadata.
#     145   keras_loader = KerasObjectLoader(metadata, object_graph_def)
# ...

# %%
result = do_evaluate('fashion_mnist', './datasets/fashion_mnist/test', 0, 5)
# Out:
# Found 10000 images belonging to 10 classes.
# ./models/fashion_mnist/v0.0.0
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-20-ebb8a5f72122> in <module>
# ----> 1 result = do_evaluate('fashion_mnist', './datasets/fashion_mnist/test', 0, 5)
#
# <ipython-input-19-145326bc8fb2> in do_evaluate(model_name, test_root, start, end)
#      12     for path in get_model_iterator(model_name, start, end):
#      13         print(path)
# ---> 14         model = tf.keras.models.load_model(os.path.abspath(os.path.expanduser(path)))
#      15         metric = model.evaluate(test_data, verbose=0)
#      16         loss.append(metric[0])
#
# ~/Jupyter/tff/lib/python3.8/site-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     204         filepath = path_to_string(filepath)
#     205         if isinstance(filepath, str):
# ...

# %%
    model = tf.keras.models.load_model(FLAGS.model)

    classes = []
    with open(os.path.join(FLAGS.model, 'labels.pickle'), 'rb') as f:
        classes = pickle.load(f)

    # prepare dataset
    image_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1/255)
    test_data = image_generator.flow_from_directory(FLAGS.data,  classes=classes, 
                                                    target_size=(32, 32), shuffle=True)

    metric = model.evaluate(test_data, verbose=0)
